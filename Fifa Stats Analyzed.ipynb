# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
plt.style.use('seaborn')

#import data set
fifa_data = pd.read_excel("Fifa Data.xlsx")
fifa_data.head()

# %%
#Goalkeepers that are in the top leagues
#Top league player Data
Leagues = ['Premier League','La Liga','Bundesliga', 'Eredivisie', 'Serie A', 'Ligue 1', 'Primeira Liga', 'Primera Division', ]
fifa_top_data = fifa_data

nottop = fifa_top_data

for i in Leagues:
    nottop = nottop.where(nottop['League'] != i)
nottop.dropna(inplace=True)

for i in nottop['Index']:
    try:
        fifa_top_data.at[i, "Name"] = None
    except:
        pass
fifa_top_data = fifa_top_data.dropna()

# %%
#Top 100 goalkeepers by OVR
top100_data = fifa_data.sort_values(by="OVR", ascending=False)
top100_data = top100_data.iloc[:101]

# %%
plt.style.use('classic')

# %%
plt.style.use('seaborn')
#Histogram of OVR Spread
plt.hist(fifa_data['OVR'], label = 'OVR of All Goalkeepers',bins = 20)
plt.xlabel('OVR')
plt.ylabel('Count')


#Histogram of Potential Spread
plt.hist(fifa_data['Potential'], alpha = .5, label = 'Potential of All Goalkeepers',bins = 20)
plt.xlabel('Potential')
plt.ylabel('Count')


plt.title('OVR and Potential of All Goalkeepers in Fifa')
plt.legend()
plt.show()


#Histogram of OVR Spread of goalkeepers in top leagues
plt.hist(fifa_top_data['OVR'], label = 'OVR of Goalkeepers',bins = 10)
plt.xlabel('OVR')
plt.ylabel('Count')


#Histogram of Potential Spread of goalkeepers in top leagues
plt.hist(fifa_top_data['Potential'], alpha = .5, label = 'Potential of Goalkeepers',bins = 10)
plt.xlabel('Potential')
plt.ylabel('Count')


plt.title('OVR and Potential of Goalkeepers in Top Leagues in Fifa')
plt.legend()
plt.show()


#Histogram of OVR Spread of goalkeepers in top leagues
plt.hist(top100_data['OVR'], label = 'OVR of Goalkeepers',bins = 5)
plt.xlabel('OVR')
plt.ylabel('Count')


#Histogram of Potential Spread of goalkeepers in top leagues
plt.hist(top100_data['Potential'], alpha = .5, label = 'Potential of Goalkeepers',bins = 5)
plt.xlabel('Potential')
plt.ylabel('Count')


plt.title('OVR and Potential of Top 100 Goalkeepers in Fifa')
plt.legend()
plt.show()

# %%
#get rid of players who have barely played (for accuracy)

df = fifa_data.where(fifa_data['Minutes Played']>180)

x, y = df['Minutes Played'], df['OVR']
plt.scatter(x,y)
plt.title('Minutes Played vs OVR')
plt.xlabel('Minutes Played')
plt.ylabel('OVR')
plt.show()

#Minutes Played vs OVR of goalkeepers in top leagues
#get rid of players who have barely played (for accuracy)


df = fifa_top_data.where(fifa_top_data['Minutes Played']>180)
x, y = df['Minutes Played'], df['OVR']
plt.scatter(x,y)
plt.title('Minutes Played vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Minutes Played')
plt.ylabel('OVR')
plt.show()


#Minunets Played vs OVR of top 100 goalkeepers
#get rid of players who have barely played (for accuracy)

df = top100_data.where(top100_data['Minutes Played']>180)

x, y = df['Minutes Played'], df['OVR']
plt.scatter(x,y)
plt.title('Minutes Played vs OVR of Top 100 Goalkeepers')
plt.xlabel('Minutes Played')
plt.ylabel('OVR')
plt.show()

# %%
#Scatter plot of OVR vs Value of player
x, y = fifa_data['OVR'], fifa_data['Value']

ax = plt.axes()
plt.scatter(x,y)

ax.set_yticks([0,10000000,20000000,30000000,40000000,50000000,60000000,70000000,80000000,90000000, 100000000,110000000,120000000])
ax.set_yticklabels(['0','10M','20M','30M','40M','50M','60M','70M','80M','90M', '100M','110M','120M'])

plt.title('Value vs OVR')
plt.xlabel('OVR')
plt.ylabel('Value (Euros)')
plt.savefig('Value vs OVR',bbox_inches='tight', facecolor = 'white')
plt.show()

#Scatter plot of OVR vs Value of goalkeepers in top leagues
x, y = fifa_top_data['OVR'], fifa_top_data['Value']

ax = plt.axes()
plt.scatter(x,y)

ax.set_yticks([0,10000000,20000000,30000000,40000000,50000000,60000000,70000000,80000000,90000000, 100000000,110000000,120000000])
ax.set_yticklabels(['0','10M','20M','30M','40M','50M','60M','70M','80M','90M', '100M','110M','120M'])

plt.title('Value vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('OVR')
plt.ylabel('Value (Euros)')
plt.show()

#Scatter plot of OVR vs Value of top 100 goalkeepers
x, y = top100_data['OVR'], top100_data['Value']

ax = plt.axes()
plt.scatter(x,y)

ax.set_yticks([0,10000000,20000000,30000000,40000000,50000000,60000000,70000000,80000000,90000000, 100000000,110000000,120000000])
ax.set_yticklabels(['0','10M','20M','30M','40M','50M','60M','70M','80M','90M', '100M','110M','120M'])

plt.title('Value vs OVR of Top 100 Goalkeepers')
plt.xlabel('OVR')
plt.ylabel('Value (Euros)')
plt.show()

# %%
#Saves v OVR
#get rid of players who have barely played (for accuracy)
df = fifa_data.where(fifa_data['Saves']>0)
x, y = df['Saves'],df['OVR']

plt.scatter(x,y)
plt.title('Saves vs OVR')
plt.xlabel('Saves')
plt.ylabel('OVR')
plt.show()

#Saves v OVR of goalkeepers in top leagues
#get rid of players who have barely played (for accuracy)
df = fifa_top_data.where(fifa_top_data['Saves']>0)
x, y = df['Saves'],df['OVR']

plt.scatter(x,y)
plt.title('Saves vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Saves')
plt.ylabel('OVR')
plt.show()

#Saves v OVR of top 100  goalkeepers
#get rid of players who have barely played (for accuracy)
df = top100_data.where(top100_data['Saves']>0)
x, y = df['Saves'],df['OVR']

plt.scatter(x,y)
plt.title('Saves vs OVR of Top 100 Goalkeepers')
plt.xlabel('Saves')
plt.ylabel('OVR')
plt.show()

# %%
#Clean Sheets v OVR
#get rid of players who have barely played (for accuracy)
df = fifa_data.where(fifa_data['Clean Sheets']>0)
x, y = df['Clean Sheets'],df['OVR']

plt.scatter(x,y)
plt.title('Clean Sheets vs OVR')
plt.xlabel('Number of Clean Sheets')
plt.ylabel('OVR')
plt.savefig('Clean Sheets vs OVR',bbox_inches='tight', facecolor = 'white')
plt.show()


#Clean Sheets v OVR of goalkeepers in top leagues
#get rid of players who have barely played (for accuracy)
df = fifa_top_data.where(fifa_top_data['Clean Sheets']>0)
x, y = df['Clean Sheets'],df['OVR']

plt.scatter(x,y)
plt.title('Clean Sheets vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Number of Clean Sheets')
plt.ylabel('OVR')
plt.show()


#Clean Sheets v OVR of top 100 goalkeepers
#get rid of players who have barely played (for accuracy)
df = top100_data.where(top100_data['Clean Sheets']>0)
x, y = df['Clean Sheets'],df['OVR']

plt.scatter(x,y)
plt.title('Clean Sheets vs OVR of Top 100 Goalkeepers')
plt.xlabel('Number of Clean Sheets')
plt.ylabel('OVR')
plt.show()

# %%
#Composure v OVR
x, y = fifa_data['Composure'],fifa_data['OVR']

plt.scatter(x,y)
plt.title('Composure vs OVR')
plt.xlabel('Composure')
plt.ylabel('OVR')
plt.savefig('Composure vs OVR',bbox_inches='tight', facecolor = 'white')
plt.show()


plt.hist2d(x,y)
plt.style.available
plt.title('Composure vs OVR')
plt.xlabel('Composure')
plt.ylabel('OVR')
plt.show()

#Composure v OVR of goalkeepers in top leagues
x, y = fifa_top_data['Composure'],fifa_top_data['OVR']

plt.scatter(x,y)
plt.title('Composure vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Composure')
plt.ylabel('OVR')
plt.show()


#Composure v OVR of top 100 goalkeepers
x, y = top100_data['Composure'],top100_data['OVR']

plt.scatter(x,y)
plt.title('Composure vs OVR of Top 100 Goalkeepers')
plt.xlabel('Composure')
plt.ylabel('OVR')
plt.show()

# %%
#Age v OVR
x, y = fifa_data['Age'],fifa_data['OVR']

plt.scatter(x,y)
plt.title('Age vs OVR')
plt.xlabel('Age')
plt.ylabel('OVR')
plt.savefig('Age vs OVR',bbox_inches='tight', facecolor = 'white')
plt.show()

#Age v OVR of goalkeeper in Top Leagues
x, y = fifa_top_data['Age'],fifa_top_data['OVR']

plt.scatter(x,y)
plt.title('Age vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Age')
plt.ylabel('OVR')
plt.show()


#Age v OVR of Top 100 goalkeepers
x, y = top100_data['Age'],top100_data['OVR']

plt.scatter(x,y)
plt.title('Age vs OVR of Top 100 Goalkeepers')
plt.xlabel('Age')
plt.ylabel('OVR')
plt.show()

# %%
#Strength v OVR
x, y = fifa_data['Strength'],fifa_data['OVR']

plt.scatter(x,y)
plt.title('Strength vs OVR')
plt.xlabel('Strength')
plt.ylabel('OVR')
plt.savefig('Strength vs OVR',bbox_inches='tight', facecolor = 'white')
plt.show()

#Strength v OVR of goalkeepers in top leagues
x, y = fifa_top_data['Strength'],fifa_top_data['OVR']

plt.scatter(x,y)
plt.title('Strength vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Strength')
plt.ylabel('OVR')
plt.show()


#Strength v OVR of top 100 goalkeepers
x, y = top100_data['Strength'],top100_data['OVR']

plt.scatter(x,y)
plt.title('Strength vs OVR of Top 100 Goalkeepers')
plt.xlabel('Strength')
plt.ylabel('OVR')
plt.show()

# %%
#distribution of height in gks
x = fifa_data['Height(cm)']
plt.hist(x = x, bins = 15)

plt.ylabel('Frequency')
plt.xlabel('Height(cm)')
plt.title('Distribution of Height in Goalkeepers')
plt.savefig('Distribution of Heights',bbox_inches='tight', facecolor = 'white')
plt.show()

# %%
#Height v OVR
x, y = fifa_data['Height(cm)'],fifa_data['OVR']

plt.scatter(x,y)
plt.title('Height vs OVR')
plt.xlabel('Height')
plt.ylabel('OVR')
plt.savefig('Height vs OVR',bbox_inches='tight', facecolor = 'white')
plt.show()


#Height v OVR of goalkeepers in top leagues
x, y = fifa_top_data['Height(cm)'],fifa_top_data['OVR']

plt.scatter(x,y)
plt.title('Height vs OVR of Goalkeepers in Top Leagues')
plt.xlabel('Height')
plt.ylabel('OVR')
plt.show()


#Height v OVR of Top 100 goalkeepers
x, y = top100_data['Height(cm)'],top100_data['OVR']

plt.scatter(x,y)
plt.title('Height vs OVR of Top 100 Goalkeepers')
plt.xlabel('Height')
plt.ylabel('OVR')
plt.show()

# %%
#Height v Potential
x, y = fifa_data['Height(cm)'],fifa_data['Potential']

plt.scatter(x,y)
plt.title('Height vs Potential')
plt.xlabel('Height')
plt.ylabel('Potential')
plt.savefig('Height vs Potential',bbox_inches='tight', facecolor = 'white')
plt.show()

#Height v Potential of goalkeepers in top leagues
x, y = fifa_top_data['Height(cm)'],fifa_top_data['Potential']

plt.scatter(x,y)
plt.title('Height vs Potential of Goalkeepers in Top Leagues')
plt.xlabel('Height')
plt.ylabel('Potential')
plt.show()


#Height v Potential of top 100 goalkeepers
x, y = top100_data['Height(cm)'],top100_data['Potential']

plt.scatter(x,y)
plt.title('Height vs Potential of Top 100 Goalkeepers')
plt.xlabel('Height')
plt.ylabel('Potential')
plt.show()

# %%
#Value vs Height
x, y = fifa_data['Height(cm)'], fifa_data['Value']

ax = plt.axes()
plt.scatter(x,y)

ax.set_yticks([0,10000000,20000000,30000000,40000000,50000000,60000000,70000000,80000000,90000000, 100000000,110000000,120000000])
ax.set_yticklabels(['0','10M','20M','30M','40M','50M','60M','70M','80M','90M', '100M','110M','120M'])

plt.title('Height vs Value')
plt.xlabel('Height(cm)')
plt.ylabel('Value (Euros)')
plt.show()

#Value vs Height of goalkeepers in top leagues
x, y = fifa_top_data['Height(cm)'], fifa_top_data['Value']

ax_ = plt.axes()
plt.scatter(x,y)

ax_.set_yticks([0,10000000,20000000,30000000,40000000,50000000,60000000,70000000,80000000,90000000, 100000000,110000000,120000000])
ax_.set_yticklabels(['0','10M','20M','30M','40M','50M','60M','70M','80M','90M', '100M','110M','120M'])

plt.title('Height vs Value of Goalkeepers in Top Leagues')
plt.xlabel('Height(cm)')
plt.ylabel('Value (Euros)')
plt.show()


#Value vs Height of top 100 goalkeepers
x, y = top100_data['Height(cm)'], top100_data['Value']

ax_ = plt.axes()
plt.scatter(x,y)

ax_.set_yticks([0,10000000,20000000,30000000,40000000,50000000,60000000,70000000,80000000,90000000, 100000000,110000000,120000000])
ax_.set_yticklabels(['0','10M','20M','30M','40M','50M','60M','70M','80M','90M', '100M','110M','120M'])

plt.title('Height vs Value of Top 100 Goalkeepers')
plt.xlabel('Height(cm)')
plt.ylabel('Value (Euros)')
plt.show()

# %%
import sklearn
from sklearn import linear_model
from sklearn.metrics import r2_score
import pickle
from scipy.stats import pearsonr

# print(fifa_data.corr()['OVR'])

# df = fifa_data[['OVR', 'Potential', 'Composure', 'Age', 'Height(cm)', 'Minutes Played', 'Saves', 'Clean Sheets', 'Reactions', 'Diving', 'Handling', 'Kicking', 'Positioning', 'Reflexes']]
# df = fifa_data[['OVR', 'Potential', 'Composure', 'Age', 'Minutes Played', 'Saves', 'Clean Sheets', 'Reactions']]
df = fifa_data[['OVR', 'Potential', 'Composure', 'Age', 'Saves', 'Reactions']]

x = df.drop(['OVR','Potential'], axis=1)
y = df['OVR']
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size = .1)

# best = 0
# for i in range(100000):

#     x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size = .05)
#     linear = linear_model.LinearRegression()
#     linear.fit(x_train,y_train)
#     acc = linear.score(x_test, y_test)
    
#     if acc > best:
#         best = acc
        
#         with open('OVR Regression Model.pickle', 'wb') as f:
#             pickle.dump(linear, f)
    

file = open('OVR Regression Model.pickle', 'rb')
model  = pickle.load(file)

predicted_ovr = model.predict(x_test)

accuracy = model.score(x_test, y_test)


print('Accuracy: ' + str(accuracy))
print('Slopes: ' + str(model.coef_))

#model for all of the data
predicted_ovr = model.predict(x)

plt.scatter(predicted_ovr,y)
plt.xlabel('Predited OVR')
plt.ylabel('Actual OVR')
plt.title('Predicted OVR vs Actual OVR')
plt.show()
print('Pearsonr: ' + str(pearsonr(predicted_ovr,y)))
sns.residplot(x = predicted_ovr,y = y)
plt.show()
# Out:
# Accuracy: 0.747421117773022
# Slopes: [0.07742925 0.02277692 0.02404384 0.49304256]
# Pearsonr: (0.8713924503319386, 0.0)

# %%
print(fifa_data.corr()['Projected Growth'])

plt.scatter(fifa_data['Age'], fifa_data['Projected Growth'])
plt.xlabel('Age')
plt.ylabel('Projected Growth')
plt.title('Age vs Projected Growth')
plt.show()

plt.scatter(fifa_data['Positioning'], fifa_data['Projected Growth'])
plt.xlabel('Positioning')
plt.ylabel('Projected Growth')
plt.title('Positioning vs Projected Growth')
plt.show()

plt.scatter(fifa_data['Reactions'], fifa_data['Projected Growth'])
plt.xlabel('Reactions')
plt.ylabel('Projected Growth')
plt.title('Reactions vs Projected Growth')
plt.show()
# Out:
# Index                       0.572365
# Age                        -0.867323
# Height(cm)                 -0.008091
# Weight(kg)                 -0.244640
# OVR                        -0.551217
# Potential                   0.212675
# Projected Growth            1.000000
# Value                      -0.097308
# Wage                       -0.209057
# Minutes Played             -0.350949
# Appearances                -0.352722
# Saves                      -0.320358
# Saves Inside the Box       -0.318720
# Penalties Save             -0.173795
# Clean Sheets               -0.326312
# League Rating               0.022918
# International Reputation   -0.199321
# Acceleration               -0.412409
# Sprint Speed               -0.439357
# Agility                    -0.311212
# Reactions                  -0.562986
# Balance                    -0.251468
# Jumping                    -0.317211
# Stamina                    -0.395116
# Strength                   -0.324315
# ...

# %%
data = fifa_data[['Index', 'League', 'Age', 'Height(cm)', 'Weight(kg)', 'OVR', 'Projected Growth', 'Value', 'Minutes Played', 'Saves', 'Clean Sheets', 'International Reputation', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Strength', 'Aggression', 'Vision', 'Composure', 'Diving', 'Handling', 'Kicking', 'Positioning', 'Reflexes']]
counts = pd.DataFrame(data['League'].value_counts())
counts = counts.where(counts['League'] > 40)
counts.dropna(inplace=True)
counts

Leagues = ['Premier League','La Liga','Bundesliga', 'Eredivisie', 'Serie A', 'Ligue 1', 'Primeira Liga', 'Primera Division', 'Pro League', 'Superliga', 'Super League', 'Major League Soccer', 'Championship' ]


nottop = data

for i in Leagues:
    nottop = nottop.where(nottop['League'] != i)
nottop.dropna(inplace=True)

for i in nottop['Index']:
    try:
        data.loc[i, "League"] = None
    except:
        pass
data = data.dropna()
data.drop('Index', axis=1)

x = data.drop('League', axis = 1)

from sklearn import linear_model, preprocessing
le = preprocessing.LabelEncoder()
leagues = le.fit_transform(list(data['League']))
y= list(leagues)
# Out:
# C:\Users\zcoch\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size = .2)

from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train,y_train)
accuracy = model.score(x_test,y_test)
print(accuracy)

# model = svm.SVC(kernel='linear')
# model.fit(x_train, y_train)
# league_pred = model.predict(x_test)
# accuracy = sklearn.metrics.accuracy_score(y_test,league_pred)
# print(accuracy)
# Out:
# 0.1242603550295858

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(x_train,y_train)
league_pred = model.predict(x_test)
accuracy = model.score(x_test,y_test)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import SGDClassifier

names = ["Nearest_Neighbors", "Polynomial_SVM", "RBF_SVM", "Gaussian_Process",
         "Gradient_Boosting", "Decision_Tree", "Extra_Trees", "Random_Forest", "Neural_Net", "AdaBoost",
         "Naive_Bayes", "QDA", "SGD"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="poly", degree=3, C=0.025),
    SVC(kernel="rbf", C=1, gamma=2),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    GradientBoostingClassifier(n_estimators=100, learning_rate=1.0),
    DecisionTreeClassifier(max_depth=5),
    ExtraTreesClassifier(n_estimators=10, min_samples_split=2),
    RandomForestClassifier(n_estimators=221, max_features='auto'),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(n_estimators=100),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
    SGDClassifier(loss="hinge", penalty="l2")]

# %%
scores = []
for name, clf in zip(names, classifiers):
    clf.fit(x_train, y_train)
    score = clf.score(x_test, y_test)
    scores.append(score)
# Out:
# C:\Users\zcoch\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:808: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
df = pd.DataFrame()
df['name'] = names
df['score'] = scores
df
# Out:
#                  name     score
# 0   Nearest_Neighbors  0.124260
# 1      Polynomial_SVM  0.142012
# 2             RBF_SVM  0.094675
# 3    Gaussian_Process  0.124260
# 4   Gradient_Boosting  0.260355
# 5       Decision_Tree  0.207101
# 6         Extra_Trees  0.331361
# 7       Random_Forest  0.343195
# 8          Neural_Net  0.071006
# 9            AdaBoost  0.171598
# 10        Naive_Bayes  0.112426
# 11                QDA  0.171598
# 12                SGD  0.023669

# %%
sns.set(style="whitegrid")
ax = sns.barplot(y="name", x="score", data=df)

# %%
from sklearn.model_selection import GridSearchCV
# model = RandomForestClassifier()


# # Number of trees in random forest
# n_estimators = np.arange(1, 1000,15)
# # Number of features to consider at every split
# max_features = ['auto', 'sqrt','log2']
# # Maximum number of levels in tree
# max_depth = list(np.arange(1, 110, 10))
# max_depth.append(None)
# # Minimum number of samples required to split a node
# min_samples_split = [2, 5, 10]
# # Minimum number of samples required at each leaf node
# min_samples_leaf = [1, 2, 4]

# random_grid = {'n_estimators': n_estimators,
#                'max_features': max_features}

# clf = GridSearchCV(estimator = model,param_grid = random_grid)
# clf.fit(x_train,y_train)
# print(pd.DataFrame(clf.cv_results_).head())
clf.best_params_,clf.best_score_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37404/3666882437.py in <module>
#      21 # clf.fit(x_train,y_train)
#      22 # print(pd.DataFrame(clf.cv_results_).head())
# ---> 23 clf.best_params_,clf.best_score_
#
# AttributeError: 'SGDClassifier' object has no attribute 'best_params_'

# %%
model = RandomForestClassifier(n_estimators=221, max_features='auto')
model.fit(x_train,y_train)
y_pred = model.predict(x)
plt.scatter(y_pred,y,alpha=.5,s=75)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('default')

#import data set
fifa_data = pd.read_excel("Fifa Data.xlsx")
fifa_data.head()


dist = np.random.normal(loc=171,scale=7.62, size = 2052)
plt.hist(dist, label = 'Normal Men',alpha = .7,  color = 'palevioletred')

plt.hist(fifa_data['Height(cm)'], alpha = .7, label = 'Male Goalkeepers', color = 'darksalmon')
plt.xlabel('Height(cm)')
plt.title('Height of Normal Men vs Height of Goalkeepers', color = 'indigo', fontweight = 'bold')
plt.legend()
plt.show()
